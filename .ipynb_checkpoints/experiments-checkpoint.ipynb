# %%
print("ciao")
# Out:
# ciao

# %%
import torch
import torchaudio
import os
import matplotlib.pyplot as plt
import torchaudio.transforms as T
import torch.nn.functional as F
from IPython.display import Audio
import pyloudnorm as pyln
from torchaudio.functional import highpass_biquad
from scipy.signal import butter, lfilter, freqz
import numpy as np
from tqdm import tqdm
import warnings
from torchaudio import transforms

# %%
from speechbrain.inference.separation import SepformerSeparation as separator
import torchaudio
model = separator.from_hparams(source="speechbrain/sepformer-whamr-enhancement")

# %%
warnings.filterwarnings("ignore")

# %%
data_folder = "data/"
instructions_folder = os.path.join(data_folder, "instructions")
sessions_folder = os.path.join(data_folder, "sessions")
normalization = True
filtering = True
enhancement = True
new_sample_rate = 8000
lowcut = 300.0
highcut = 3000.0
cross_correlations_folder = os.path.join(data_folder, "cross_correlation")

# %%
os.makedirs(cross_correlations_folder, exist_ok=True)

# %%
def load_audio(path, new_sample_rate=None):
    waveform, sample_rate = torchaudio.load(path)
    if new_sample_rate:
        resampler = T.Resample(sample_rate, new_sample_rate, dtype=waveform.dtype)
        waveform = resampler(waveform)
        return waveform, new_sample_rate
    return waveform, sample_rate

# %%
def normalize_volume(data, rate, new_loudness=-23):   
    # measure the loudness first 
    meter = pyln.Meter(rate) # create BS.1770 meter
    loudness = meter.integrated_loudness(data)
    
    # loudness normalize audio to -12 dB LUFS
    loudness_normalized_audio = pyln.normalize.loudness(data, loudness, -12.0)
    return loudness_normalized_audio

# %%
def plot_waveform(waveform, sample_rate):
    waveform = waveform.numpy()

    num_channels, num_frames = waveform.shape
    time_axis = torch.arange(0, num_frames) / sample_rate

    figure, axes = plt.subplots(num_channels, 1)
    if num_channels == 1:
        axes = [axes]
    for c in range(num_channels):
        axes[c].plot(time_axis, waveform[c], linewidth=1)
        axes[c].grid(True)
        if num_channels > 1:
            axes[c].set_ylabel(f"Channel {c+1}")
    figure.suptitle("waveform")

# %%
def plot_specgram(waveform, sample_rate, title="Spectrogram"):
    waveform = waveform.numpy()

    num_channels, num_frames = waveform.shape

    figure, axes = plt.subplots(num_channels, 1)
    if num_channels == 1:
        axes = [axes]
    for c in range(num_channels):
        axes[c].specgram(waveform[c], Fs=sample_rate)
        if num_channels > 1:
            axes[c].set_ylabel(f"Channel {c+1}")
    figure.suptitle(title)

# %%
def butter_highpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='high', analog=False)
    return b, a

def highpass_filter(data, cutoff, fs, order=5):
    b, a = butter_highpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y

def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs  # Nyquist Frequency
    low = lowcut / nyq  # Normalize lowcut
    high = highcut / nyq  # Normalize highcut
    b, a = butter(order, [low, high], btype='band')
    return b, a

def bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

# %%
# INSTRUCTION

# %%
"""
waveform_instruction = model.separate_file(path=os.path.join(instructions_folder, "10wordrep_explanation.wav"))
waveform_instruction = waveform_instruction.squeeze(2)
sr = 8000
"""
# Out:
# '\nwaveform_instruction = model.separate_file(path=os.path.join(instructions_folder, "10wordrep_explanation.wav"))\nwaveform_instruction = waveform_instruction.squeeze(2)\nsr = 8000\n'

# %%
waveform_instruction, sr = load_audio(os.path.join(instructions_folder, "10wordrep_explanation.wav"), new_sample_rate=new_sample_rate)
#waveform_instruction, sr = load_audio(os.path.join(instructions_folder, "25nonword4.wav"), new_sample_rate=new_sample_rate)

# %%
if filtering:
    waveform_instruction = torch.tensor(bandpass_filter(waveform_instruction, lowcut=lowcut, highcut=highcut, fs=sr))

# %%
if normalization:
    waveform_instruction = torch.tensor(normalize_volume(waveform_instruction[0].numpy(), sr).reshape(1, -1))

# %%
# waveform_instruction = waveform_instruction[:, :3*sr]

# %%
waveform_instruction.shape
# Out:
# torch.Size([1, 134379])

# %%
sr
# Out:
# 8000

# %%
"""
waveform_session = model.separate_file(path=os.path.join(sessions_folder, "5031633_speech_language_SHORT.wav"))
waveform_session = waveform_session.squeeze(2)
sr = 8000
"""
# Out:
# '\nwaveform_session = model.separate_file(path=os.path.join(sessions_folder, "5031633_speech_language_SHORT.wav"))\nwaveform_session = waveform_session.squeeze(2)\nsr = 8000\n'

# %%
waveform_session, sr = load_audio(os.path.join(sessions_folder, "5031633_speech_language_SHORT.wav"), new_sample_rate=new_sample_rate)
#waveform_session, sr = load_audio(os.path.join(sessions_folder, "start.wav"), new_sample_rate=None)

# %%
if filtering:
    waveform_session = torch.tensor(bandpass_filter(waveform_session, lowcut=lowcut, highcut=highcut, fs=sr))

# %%
if normalization:
    waveform_session = torch.tensor(normalize_volume(waveform_session[0].numpy(), sr).reshape(1, -1))

# %%
sr
# Out:
# 8000

# %%
waveform_session.shape
# Out:
# torch.Size([1, 283660])

# %%
#waveform_session = waveform_session[:, 340*sr:365*sr]

# %%
# waveform_session = waveform_session[:,:waveform_instruction.shape[1]]

# %%
Audio(waveform_instruction.numpy(), rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(waveform_session.numpy(), rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
waveform_instruction.shape
# Out:
# torch.Size([1, 134379])

# %%
plot_waveform(waveform_instruction, sr)

# %%
waveform_session.shape
# Out:
# torch.Size([1, 283660])

# %%
#transform = transforms.Vad(sample_rate=sr)
# waveform_instruction = transform(waveform_instruction)

# %%
plot_waveform(waveform_instruction, sr)

# %%
# waveform_instruction.shape

# %%
"""
transform = transforms.Vad(sample_rate=sr)
waveform_instruction = torch.flip(waveform_instruction, dims=[1])
waveform_instruction = transform(waveform_instruction)
waveform_instruction = torch.flip(waveform_instruction, dims=[1])
"""
# Out:
# '\ntransform = transforms.Vad(sample_rate=sr)\nwaveform_instruction = torch.flip(waveform_instruction, dims=[1])\nwaveform_instruction = transform(waveform_instruction)\nwaveform_instruction = torch.flip(waveform_instruction, dims=[1])\n'

# %%
# waveform_instruction

# %%
plot_waveform(waveform_instruction, sr)

# %%
plot_waveform(waveform_session[:,:], sr)

# %%
# SPECTROGRAM

# %%
plot_specgram(waveform_instruction, sr)

# %%
plot_specgram(waveform_session, sr)

# %%
waveform_instruction.shape
# Out:
# torch.Size([1, 134379])

# %%
waveform_session.shape
# Out:
# torch.Size([1, 283660])

# %%
waveform_instruction = waveform_instruction.squeeze()

# %%
waveform_session = waveform_session.squeeze()

# %%
#waveform_instruction_flipped = torch.flip(waveform_instruction, [2])

# %%
"""
# Compute cross-correlation
cross_correlation = F.conv1d(waveform_session, waveform_instruction_flipped, padding='same')

# Find the index of the highest correlation
max_correlation, max_index = torch.max(cross_correlation, dim=2)

print(f"Maximum correlation is at index: {max_index.item()}")
"""
# Out:
# '\n# Compute cross-correlation\ncross_correlation = F.conv1d(waveform_session, waveform_instruction_flipped, padding=\'same\')\n\n# Find the index of the highest correlation\nmax_correlation, max_index = torch.max(cross_correlation, dim=2)\n\nprint(f"Maximum correlation is at index: {max_index.item()}")\n'

# %%
def normalize_cross_correlation(cross_corr, signal1, signal2):
    """
    Normalize the cross-correlation values to be between 0 and 1.

    Parameters:
    - cross_corr: The computed cross-correlation values.
    - signal1: The first signal (array).
    - signal2: The second signal (array).

    Returns:
    - Normalized cross-correlation array.
    """
    # Compute the energy (sum of squares) of each signal
    energy_signal1 = np.sum(signal1 ** 2)
    energy_signal2 = np.sum(signal2 ** 2)

    # Normalize the cross-correlation values
    normalization_factor = np.sqrt(energy_signal1 * energy_signal2)
    normalized_cross_corr = cross_corr / normalization_factor

    return normalized_cross_corr

# %%
cross_correlation = np.correlate(waveform_session, waveform_instruction, mode='full')

# The peak of the cross-correlation can indicate the position where the instruction_waveform is most similar to a part of the session_waveform
peak_index = np.argmax(cross_correlation)
peak_value = cross_correlation[peak_index]

print(f"Peak Index: {peak_index}, Peak Value: {peak_value}")
# Out:
# Peak Index: 161977, Peak Value: 1542.4934337135387

# %%
def normalize_array_to_0_1(arr):
    arr_min = np.min(arr)
    arr_max = np.max(arr)
    normalized_arr = (arr - arr_min) / (arr_max - arr_min)
    return normalized_arr

def standardize_array(arr):
    arr_mean = np.mean(arr)
    arr_std = np.std(arr)
    standardized_arr = (arr - arr_mean) / arr_std
    return standardized_arr

# %%
standardized_normalized_cross_corr = standardize_array(cross_correlation)
normalized_standardized_cross_corr = normalize_array_to_0_1(standardized_normalized_cross_corr)
max_corr_index = np.argmax(standardized_normalized_cross_corr)
max_corr_value = standardized_normalized_cross_corr[max_corr_index]
print(f"Peak Index: {max_corr_index}, Peak Value: {max_corr_value}")
# Out:
# Peak Index: 161977, Peak Value: 85.23807692446657

# %%
normalized_cross_corr = normalize_cross_correlation(cross_correlation, waveform_session.numpy(), waveform_instruction.numpy())

# Find the index and value of the maximum normalized correlation
max_corr_index = np.argmax(normalized_cross_corr)
max_corr_value = normalized_cross_corr[max_corr_index]
print(f"Maximum normalized correlation at index: {max_corr_index}, value: {max_corr_value}")

# %%
shift = (peak_index - (len(waveform_instruction) - 1))/ sr
shift

# %%
standardized_normalized_cross_corr = standardize_array(normalized_cross_corr)

# %%
max_corr_index = np.argmax(standardized_normalized_cross_corr)
max_corr_value = standardized_normalized_cross_corr[max_corr_index]
print(f"Maximum normalized correlation at index: {max_corr_index}, value: {max_corr_value}")

# %%
plt.figure(figsize=(10, 6))
plt.plot(standardized_normalized_cross_corr, label='Normalized Cross-Correlation')
plt.xlabel('Lag')
plt.ylabel('Normalized Cross-Correlation')
plt.title('Normalized Cross-Correlation between Two Signals')
plt.legend()
plt.grid(True)
plt.show()

# %%
def save_cross_correlation(cross_correlation, file_path):
    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(cross_correlation, label='Normalized Cross-Correlation')
    plt.xlabel('Lag')
    plt.ylabel('Normalized Cross-Correlation')
    plt.title('Normalized Cross-Correlation between Two Signals')
    plt.legend()
    plt.grid(True)
    # plt.show()
    plt.savefig(file_path)

# %%
def cross_correlation_fft(signal1, signal2):
    # Pad signals
    n = len(signal1) + len(signal2) - 1
    padded_signal1 = np.pad(signal1, (0, n - len(signal1)))
    padded_signal2 = np.pad(signal2, (0, n - len(signal2)))
    
    # FFT of both signals
    fft_signal1 = np.fft.fft(padded_signal1)
    fft_signal2 = np.fft.fft(padded_signal2)
    
    # Pointwise multiply and inverse FFT
    result = np.fft.ifft(fft_signal1 * np.conj(fft_signal2))
    
    # Return the real part (to handle numerical imprecisions)
    return np.real(result)

# %%
"""
cross_corr = cross_correlation_fft(waveform_session, waveform_instruction)

# Find the index of the maximum correlation
max_corr_index = np.argmax(cross_corr)
print(f"Maximum correlation at index: {max_corr_index}")
"""

# %%
"""
shift = (max_corr_index - (len(waveform_instruction) - 1))/ sr
shift
"""

# %%
#standardized_normalized_cross_corr = standardize_array(normalized_cross_corr)

# %%
"""
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(standardized_normalized_cross_corr, label='Normalized Cross-Correlation')
plt.xlabel('Lag')
plt.ylabel('Normalized Cross-Correlation')
plt.title('Normalized Cross-Correlation between Two Signals')
plt.legend()
plt.grid(True)
plt.show()
"""

# %%
#738744/16000

# %%
#cross_correlation.shape

# %%
instruction_file_paths = [os.path.join(instructions_folder, instruction_filename) for instruction_filename in os.listdir(instructions_folder) if instruction_filename.endswith(".wav")]
session_file_paths = [os.path.join(sessions_folder, session_filename) for session_filename in os.listdir(sessions_folder) if session_filename.endswith(".wav")]

# %%
sessions_peaks = []

for session_file_path in tqdm(sorted(session_file_paths), desc='Sessions folders', leave=False):
    peaks = []
    
    # print(sessions_folder)
    waveform_session, sr = load_audio(session_file_path, new_sample_rate=new_sample_rate)
    if filtering:
        waveform_session = torch.tensor(bandpass_filter(waveform_session, lowcut=lowcut, highcut=highcut, fs=sr))
    if normalization:
        waveform_session = torch.tensor(normalize_volume(waveform_session[0].numpy(), sr).reshape(1, -1))
    waveform_session = waveform_session.squeeze()

    for instruction_file_path in tqdm(sorted(instruction_file_paths), desc='Instruction files'):
        print(instruction_file_path)
        waveform_instruction, sr = load_audio(instruction_file_path, new_sample_rate=new_sample_rate)
        instruction_duration = waveform_instruction.shape[1]/new_sample_rate
        print(f"Duration: {instruction_duration}")
        if filtering:
            waveform_instruction = torch.tensor(bandpass_filter(waveform_instruction, lowcut=lowcut, highcut=highcut, fs=sr))
        if normalization:
            waveform_instruction = torch.tensor(normalize_volume(waveform_instruction[0].numpy(), sr).reshape(1, -1))
        waveform_instruction = waveform_instruction.squeeze()

        cross_correlation = np.correlate(waveform_session, waveform_instruction, mode='full')
        normalized_cross_corr = normalize_cross_correlation(cross_correlation, waveform_session.numpy(), waveform_instruction.numpy())
        standardized_normalized_cross_corr = standardize_array(normalized_cross_corr)
        max_corr_index = np.argmax(standardized_normalized_cross_corr)
        max_corr_value = standardized_normalized_cross_corr[max_corr_index]
        print(f"Maximum standardized correlation at index: {max_corr_index}, value: {max_corr_value}")
        if max_corr_value < threshold:
        shift = (max_corr_index - (len(waveform_instruction) - 1))/ sr
        print(f"Shift: {shift}")
        save_cross_correlation(standardized_normalized_cross_corr, os.path.join(cross_correlations_folder, f"{os.path.basename(instruction_file_path)[:-4]}_{os.path.basename(session_file_path)[:-4]}.png"))
        save_cross_correlation(standardized_normalized_cross_corr, os.path.join(cross_correlations_folder, f"{os.path.basename(instruction_file_path)[:-4]}_{os.path.basename(session_file_path)[:-4]}.svg"))
        
        peaks.append([shift, os.path.basename(instruction_file_path)[:-4]])
    sessions_peaks.append(peaks)


# TODO: ADD CHECK WITH THRESHOLD
# TODO: ADAPT waveform_session to speed up the process (and maybe optimize it)
